# %%
# !pip install pytesseract

# %%
import pytesseract
from PIL import Image

image_path = "/content/drive/MyDrive/자연어처리/제목 없음.png"
image = Image.open(image_path)

extracted_text = pytesseract.image_to_string(image, lang="kor+eng")

extracted_text
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pytesseract/pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     274     try:
# --> 275         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     276     except OSError as e:
#
# /usr/lib/python3.11/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1025
# -> 1026             self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                                 pass_fds, cwd, env,
#
# ...
